# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
#importing the libraries
import numpy as np
import pandas as pd

# %% [markdown]
# **IMPORTING THE** **DATASET**
# ---

# %%
fraudtrain=pd.read_csv('/content/fraudTrain.csv')
fraudtest=pd.read_csv('/content/fraudTest.csv')
print(fraudtrain.head())

# %% [markdown]
# #FEATURES

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
#encoding categorical features by selecting columns.
select=['amt','lat','long','is_fraud','merch_lat','merch_long','unix_time']
category_feature=['merchant','category','job']


#label encoding
label_encoding=LabelEncoder()
for feature in category_feature:
  fraudtrain[feature] =label_encoding.fit_transform(fraudtrain[feature])

#define x and y for model training.
X=fraudtrain[feature]
y=fraudtrain['is_fraud']

# %% [markdown]
# # RESAMPLING THE MINORITY CLASS

# %%
from sklearn.utils import resample
majority_class =fraudtrain[fraudtrain['is_fraud']==0]
minority_class=fraudtrain[fraudtrain['is_fraud']==1]
minority_unsampled_train=resample(minority_class,replace=True,n_samples=len(majority_class),random_state=35)
fraudtrain=pd.concat([majority_class,minority_class])

# %% [markdown]
# # SPLITING THE DATA

# %%
#split the data into training and testing sets.
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=35)

# %% [markdown]
# # IMPORTING LOGISTICREGRESSION AND EVALUATING THE MODEL

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

# Create a new LogisticRegression object
logistic_model = LogisticRegression()

# Assuming X_train is your 1D array
X_train_reshaped = X_train.reshape(-1, 1)

# Assuming y_train is your 1D array
y_train_reshaped = y_train.reshape(-1, 1)

# Create a new DataFrame object from the ndarray
X_train_df = pd.DataFrame(X_train_reshaped, columns=['column_name'])
y_train_df = pd.DataFrame(y_train_reshaped, columns=['column_name'])

# Train the model using the DataFrames
logistic_model.fit(X_train_df, y_train_df)

# Make predictions on the test data
y_prediction = logistic_model.predict(X_test_reshaped)

# Truncate y_prediction to the same length as y_true
y_prediction = y_prediction[:len(y_true)]

# Evaluating the model
accuracy_model = accuracy_score(y_true, y_prediction)
score_model = roc_auc_score(y_true, y_prediction)
print("LOGISTIC REGRESSION MODEL EVALUATION::  ")
print(f"accuracy: {accuracy_model}")
print(f"not accuracy : {score_model}")

# %%
#THANKYOU CODSOFT
